# %%
import glob
import tensorflow as tf 
import numpy as np
import pandas as pd

# %%
path = "/Users/kyletopasna/Documents/hunter/ISCX CIC/CIC-IDS-2017/MachineLearningCVE/"

# %% [raw]
# Before Changing dtypes
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445909 entries, 0 to 445908
# Data columns (total 79 columns):
#  Destination Port               445909 non-null int64
#  Flow Duration                  445909 non-null int64
#  Total Fwd Packets              445909 non-null int64
#  Total Backward Packets         445909 non-null int64
# Total Length of Fwd Packets     445909 non-null int64
#  Total Length of Bwd Packets    445909 non-null int64
#  Fwd Packet Length Max          445909 non-null int64
#  Fwd Packet Length Min          445909 non-null int64
#  Fwd Packet Length Mean         445909 non-null float64
#  Fwd Packet Length Std          445909 non-null float64
# Bwd Packet Length Max           445909 non-null int64
#  Bwd Packet Length Min          445909 non-null int64
#  Bwd Packet Length Mean         445909 non-null float64
#  Bwd Packet Length Std          445909 non-null float64
# Flow Bytes/s                    445708 non-null object
#  Flow Packets/s                 445909 non-null object
#  Flow IAT Mean                  445909 non-null float64
#  Flow IAT Std                   445909 non-null float64
#  Flow IAT Max                   445909 non-null int64
#  Flow IAT Min                   445909 non-null int64
# Fwd IAT Total                   445909 non-null int64
#  Fwd IAT Mean                   445909 non-null float64
#  Fwd IAT Std                    445909 non-null float64
#  Fwd IAT Max                    445909 non-null int64
#  Fwd IAT Min                    445909 non-null int64
# Bwd IAT Total                   445909 non-null int64
#  Bwd IAT Mean                   445909 non-null float64
#  Bwd IAT Std                    445909 non-null float64
#  Bwd IAT Max                    445909 non-null int64
#  Bwd IAT Min                    445909 non-null int64
# Fwd PSH Flags                   445909 non-null int64
#  Bwd PSH Flags                  445909 non-null int64
#  Fwd URG Flags                  445909 non-null int64
#  Bwd URG Flags                  445909 non-null int64
#  Fwd Header Length              445909 non-null int64
#  Bwd Header Length              445909 non-null int64
# Fwd Packets/s                   445909 non-null float64
#  Bwd Packets/s                  445909 non-null float64
#  Min Packet Length              445909 non-null int64
#  Max Packet Length              445909 non-null int64
#  Packet Length Mean             445909 non-null float64
#  Packet Length Std              445909 non-null float64
#  Packet Length Variance         445909 non-null float64
# FIN Flag Count                  445909 non-null int64
#  SYN Flag Count                 445909 non-null int64
#  RST Flag Count                 445909 non-null int64
#  PSH Flag Count                 445909 non-null int64
#  ACK Flag Count                 445909 non-null int64
#  URG Flag Count                 445909 non-null int64
#  CWE Flag Count                 445909 non-null int64
#  ECE Flag Count                 445909 non-null int64
#  Down/Up Ratio                  445909 non-null int64
#  Average Packet Size            445909 non-null float64
#  Avg Fwd Segment Size           445909 non-null float64
#  Avg Bwd Segment Size           445909 non-null float64
#  Fwd Header Length.1            445909 non-null int64
# Fwd Avg Bytes/Bulk              445909 non-null int64
#  Fwd Avg Packets/Bulk           445909 non-null int64
#  Fwd Avg Bulk Rate              445909 non-null int64
#  Bwd Avg Bytes/Bulk             445909 non-null int64
#  Bwd Avg Packets/Bulk           445909 non-null int64
# Bwd Avg Bulk Rate               445909 non-null int64
# Subflow Fwd Packets             445909 non-null int64
#  Subflow Fwd Bytes              445909 non-null int64
#  Subflow Bwd Packets            445909 non-null int64
#  Subflow Bwd Bytes              445909 non-null int64
# Init_Win_bytes_forward          445909 non-null int64
#  Init_Win_bytes_backward        445909 non-null int64
#  act_data_pkt_fwd               445909 non-null int64
#  min_seg_size_forward           445909 non-null int64
# Active Mean                     445909 non-null float64
#  Active Std                     445909 non-null float64
#  Active Max                     445909 non-null int64
#  Active Min                     445909 non-null int64
# Idle Mean                       445909 non-null float64
#  Idle Std                       445909 non-null float64
#  Idle Max                       445909 non-null int64
#  Idle Min                       445909 non-null int64
#  Label                          445909 non-null object
# dtypes: float64(22), int64(54), object(3)
# memory usage: 268.8+ MB

# %% [raw]
# After changing dtypes
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445909 entries, 0 to 445908
# Data columns (total 79 columns):
#  Destination Port               445909 non-null int32
#  Flow Duration                  445909 non-null int32
#  Total Fwd Packets              445909 non-null int32
#  Total Backward Packets         445909 non-null int32
# Total Length of Fwd Packets     445909 non-null int32
#  Total Length of Bwd Packets    445909 non-null int32
#  Fwd Packet Length Max          445909 non-null int32
#  Fwd Packet Length Min          445909 non-null int32
#  Fwd Packet Length Mean         445909 non-null float16
#  Fwd Packet Length Std          445909 non-null float16
# Bwd Packet Length Max           445909 non-null int32
#  Bwd Packet Length Min          445909 non-null int32
#  Bwd Packet Length Mean         445909 non-null float16
#  Bwd Packet Length Std          445909 non-null float16
# Flow Bytes/s                    445708 non-null category
#  Flow Packets/s                 445909 non-null category
#  Flow IAT Mean                  445909 non-null float16
#  Flow IAT Std                   445909 non-null float16
#  Flow IAT Max                   445909 non-null int32
#  Flow IAT Min                   445909 non-null int32
# Fwd IAT Total                   445909 non-null int32
#  Fwd IAT Mean                   445909 non-null float16
#  Fwd IAT Std                    445909 non-null float16
#  Fwd IAT Max                    445909 non-null int32
#  Fwd IAT Min                    445909 non-null int32
# Bwd IAT Total                   445909 non-null int32
#  Bwd IAT Mean                   445909 non-null float16
#  Bwd IAT Std                    445909 non-null float16
#  Bwd IAT Max                    445909 non-null int32
#  Bwd IAT Min                    445909 non-null int32
# Fwd PSH Flags                   445909 non-null int32
#  Bwd PSH Flags                  445909 non-null int32
#  Fwd URG Flags                  445909 non-null int32
#  Bwd URG Flags                  445909 non-null int32
#  Fwd Header Length              445909 non-null int32
#  Bwd Header Length              445909 non-null int32
# Fwd Packets/s                   445909 non-null float16
#  Bwd Packets/s                  445909 non-null float16
#  Min Packet Length              445909 non-null int32
#  Max Packet Length              445909 non-null int32
#  Packet Length Mean             445909 non-null float16
#  Packet Length Std              445909 non-null float16
#  Packet Length Variance         445909 non-null float16
# FIN Flag Count                  445909 non-null int32
#  SYN Flag Count                 445909 non-null int32
#  RST Flag Count                 445909 non-null int32
#  PSH Flag Count                 445909 non-null int32
#  ACK Flag Count                 445909 non-null int32
#  URG Flag Count                 445909 non-null int32
#  CWE Flag Count                 445909 non-null int32
#  ECE Flag Count                 445909 non-null int32
#  Down/Up Ratio                  445909 non-null int32
#  Average Packet Size            445909 non-null float16
#  Avg Fwd Segment Size           445909 non-null float16
#  Avg Bwd Segment Size           445909 non-null float16
#  Fwd Header Length.1            445909 non-null int32
# Fwd Avg Bytes/Bulk              445909 non-null int32
#  Fwd Avg Packets/Bulk           445909 non-null int32
#  Fwd Avg Bulk Rate              445909 non-null int32
#  Bwd Avg Bytes/Bulk             445909 non-null int32
#  Bwd Avg Packets/Bulk           445909 non-null int32
# Bwd Avg Bulk Rate               445909 non-null int32
# Subflow Fwd Packets             445909 non-null int32
#  Subflow Fwd Bytes              445909 non-null int32
#  Subflow Bwd Packets            445909 non-null int32
#  Subflow Bwd Bytes              445909 non-null int32
# Init_Win_bytes_forward          445909 non-null int32
#  Init_Win_bytes_backward        445909 non-null int32
#  act_data_pkt_fwd               445909 non-null int32
#  min_seg_size_forward           445909 non-null int32
# Active Mean                     445909 non-null float16
#  Active Std                     445909 non-null float16
#  Active Max                     445909 non-null int32
#  Active Min                     445909 non-null int32
# Idle Mean                       445909 non-null float16
#  Idle Std                       445909 non-null float16
#  Idle Max                       445909 non-null int32
#  Idle Min                       445909 non-null int32
#  Label                          445909 non-null category
# dtypes: category(3), float16(22), int32(54)
# memory usage: 138.0 MB

# %%
dtypes = {
    ' Destination Port' : 'int32',
    ' Flow Duration' : 'int32',
    ' Total Fwd Packets' :  'int32',
    ' Total Backward Packets' : 'int32',
    'Total Length of Fwd Packets' : 'int32',
    ' Total Length of Bwd Packets' : 'int32', 
    ' Fwd Packet Length Max' : 'int32',
    ' Fwd Packet Length Min' : 'int32', 
    ' Fwd Packet Length Mean' : 'float16',
    ' Fwd Packet Length Std' : 'float16', 
    'Bwd Packet Length Max': 'int32',
    ' Bwd Packet Length Min' : 'int32', 
    ' Bwd Packet Length Mean' : 'float16',
    ' Bwd Packet Length Std' : 'float16', 
    'Flow Bytes/s' : 'category', 
    ' Flow Packets/s' : 'category',
    ' Flow IAT Mean' : 'float16', 
    ' Flow IAT Std' : 'float16', 
    ' Flow IAT Max' : 'int32', 
    ' Flow IAT Min' : 'int32',
    'Fwd IAT Total' : 'int32', 
    ' Fwd IAT Mean' : 'float16', 
    ' Fwd IAT Std' : 'float16', 
    ' Fwd IAT Max' : 'int32',
    ' Fwd IAT Min' : 'int32', 
    'Bwd IAT Total' : 'int32', 
    ' Bwd IAT Mean' : 'float16', 
    ' Bwd IAT Std' : 'float16',
    ' Bwd IAT Max' : 'int32', 
    ' Bwd IAT Min' : 'int32', 
    'Fwd PSH Flags' : 'int32', 
    ' Bwd PSH Flags' : 'int32',
    ' Fwd URG Flags' : 'int32', 
    ' Bwd URG Flags' : 'int32', 
    ' Fwd Header Length' : 'int32',
    ' Bwd Header Length' : 'int32', 
    'Fwd Packets/s' : 'float16', 
    ' Bwd Packets/s' : 'float16',
    ' Min Packet Length' : 'int32', 
    ' Max Packet Length' : 'int32', 
    ' Packet Length Mean' : 'float16',
    ' Packet Length Std' : 'float16', 
    ' Packet Length Variance' : 'float16', 
    'FIN Flag Count' : 'int32',
    ' SYN Flag Count' : 'int32', 
    ' RST Flag Count' : 'int32', 
    ' PSH Flag Count' : 'int32',
    ' ACK Flag Count' : 'int32', 
    ' URG Flag Count' : 'int32', 
    ' CWE Flag Count' : 'int32',
    ' ECE Flag Count' : 'int32', 
    ' Down/Up Ratio' : 'int32', 
    ' Average Packet Size' : 'float16',
    ' Avg Fwd Segment Size' : 'float16', 
    ' Avg Bwd Segment Size' : 'float16',
    ' Fwd Header Length.1' : 'int32', 
    'Fwd Avg Bytes/Bulk' : 'int32', 
    ' Fwd Avg Packets/Bulk' : 'int32',
    ' Fwd Avg Bulk Rate' : 'int32', 
    ' Bwd Avg Bytes/Bulk' : 'int32', 
    ' Bwd Avg Packets/Bulk' : 'int32',
    'Bwd Avg Bulk Rate' : 'int32', 
    'Subflow Fwd Packets' : 'int32', 
    ' Subflow Fwd Bytes' : 'int32',
    ' Subflow Bwd Packets' : 'int32', 
    ' Subflow Bwd Bytes' : 'int32', 
    'Init_Win_bytes_forward' : 'int32',
    ' Init_Win_bytes_backward' : 'int32', 
    ' act_data_pkt_fwd' : 'int32',
    ' min_seg_size_forward' : 'int32', 
    'Active Mean' : 'float16', 
    ' Active Std' : 'float16', 
    ' Active Max' : 'int32',
    ' Active Min' : 'int32', 
    'Idle Mean' : 'float16', 
    ' Idle Std' : 'float16', 
    ' Idle Max' : 'int32', 
    ' Idle Min' : 'int32',
    ' Label' : 'category',
}

# %%
data = pd.read_csv(path + "Tuesday-WorkingHours.pcap_ISCX.csv", dtype=dtypes)

# %%
data.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445909 entries, 0 to 445908
# Data columns (total 79 columns):
#  Destination Port               445909 non-null int32
#  Flow Duration                  445909 non-null int32
#  Total Fwd Packets              445909 non-null int32
#  Total Backward Packets         445909 non-null int32
# Total Length of Fwd Packets     445909 non-null int32
#  Total Length of Bwd Packets    445909 non-null int32
#  Fwd Packet Length Max          445909 non-null int32
#  Fwd Packet Length Min          445909 non-null int32
#  Fwd Packet Length Mean         445909 non-null float16
#  Fwd Packet Length Std          445909 non-null float16
# Bwd Packet Length Max           445909 non-null int32
#  Bwd Packet Length Min          445909 non-null int32
#  Bwd Packet Length Mean         445909 non-null float16
#  Bwd Packet Length Std          445909 non-null float16
# Flow Bytes/s                    445708 non-null category
# ...

# %%
columns = data.columns.str.lower().str.strip().str.replace(" ","_")
print(columns)
# Out:
# Index(['destination_port', 'flow_duration', 'total_fwd_packets',
#        'total_backward_packets', 'total_length_of_fwd_packets',
#        'total_length_of_bwd_packets', 'fwd_packet_length_max',
#        'fwd_packet_length_min', 'fwd_packet_length_mean',
#        'fwd_packet_length_std', 'bwd_packet_length_max',
#        'bwd_packet_length_min', 'bwd_packet_length_mean',
#        'bwd_packet_length_std', 'flow_bytes/s', 'flow_packets/s',
#        'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min',
#        'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max',
#        'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std',
#        'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'bwd_psh_flags',
#        'fwd_urg_flags', 'bwd_urg_flags', 'fwd_header_length',
#        'bwd_header_length', 'fwd_packets/s', 'bwd_packets/s',
#        'min_packet_length', 'max_packet_length', 'packet_length_mean',
# ...

# %%
data.columns = columns

# %%
data["fwd_packet_length_mean"].nlargest(5)
# Out:
# 314705    4672.000000
# 125307    4194.194444
# 130030    4011.763158
# 130047    4011.763158
# 2304      3993.486486
# Name: fwd_packet_length_mean, dtype: float64

# %% [markdown]
# # Create Full and Training Datasets

# %% [markdown]
# <h2> Load full dataset and training dataset from cic_2017_setup </h2>

# %%
import cic_2017_setup
full_data, training_data = cic_2017_setup.setup()

# %%
training_data.shape
# Out:
# (5661486, 79)

# %%
training_data = training_data.sample(frac=1).reset_index(drop=True)

# %%
training_data.to_csv("train.csv", header=True, mode='a', index=False)

# %%
full_data = full_data.sample(frac=1).reset_index(drop=True)
full_data.to_csv("test.csv", header=True, mode='a', index=False)

# %%
full_data.shape
# Out:
# (2830743, 79)

# %%
dtypes = {
    "destination_port":               "int32",
"flow_duration":                  "int32",
"total_fwd_packets":              "int32",
"total_backward_packets":         "int32",
"total_length_of_fwd_packets":    "int32",
"total_length_of_bwd_packets":    "int32",
"fwd_packet_length_max":         "int32",
"fwd_packet_length_min":          "int32",
"fwd_packet_length_mean":         "float32",
"fwd_packet_length_std":          "float32",
"bwd_packet_length_max":          "int32",
"bwd_packet_length_min":          "int32",
"bwd_packet_length_mean":         "float32",
"bwd_packet_length_std":          "float32",
"flow_bytes/s":                   "float32",
"flow_packets/s":                 "float32",
"flow_iat_mean":                  "float32",
"flow_iat_std":                   "float32",
"flow_iat_max":                   "int32",
"flow_iat_min":                   "int32",
"fwd_iat_total":                  "int32",
"fwd_iat_mean":                   "float32",
"fwd_iat_std":                    "float32",
"fwd_iat_max":                    "int32",
"fwd_iat_min":                    "int32",
"bwd_iat_total":                  "int32",
"bwd_iat_mean":                   "float32",
"bwd_iat_std":                    "float32",
"bwd_iat_max":                    "int32",
"bwd_iat_min":                    "int32",
"fwd_psh_flags":                  "int32",
"bwd_psh_flags":                  "int32",
"fwd_urg_flags":                  "int32",
"bwd_urg_flags":                  "int32",
"fwd_header_length":              "int32",
"bwd_header_length":              "int32",
"fwd_packets/s":                  "float32",
"bwd_packets/s":                  "float32",
"min_packet_length":              "int32",
"max_packet_length":              "int32",
"packet_length_mean":             "float32",
"packet_length_std":              "float32",
"packet_length_variance":         "float32",
"fin_flag_count":                 "int32",
"syn_flag_count":                 "int32",
"rst_flag_count":                 "int32",
"psh_flag_count":                 "int32",
"ack_flag_count":                 "int32",
"urg_flag_count":                 "int32",
"cwe_flag_count":                 "int32",
"ece_flag_count":                 "int32",
"down/up_ratio":                  "int32",
"average_packet_size":            "float32",
"avg_fwd_segment_size":           "float32",
"avg_bwd_segment_size":           "float32",
"fwd_header_length.1":            "int32",
"fwd_avg_bytes/bulk":             "int32",
"fwd_avg_packets/bulk":           "int32",
"fwd_avg_bulk_rate":             "int32",
"bwd_avg_bytes/bulk":             "int32",
"bwd_avg_packets/bulk":           "int32",
"bwd_avg_bulk_rate":              "int32",
"subflow_fwd_packets":            "int32",
"subflow_fwd_bytes":              "int32",
"subflow_bwd_packets":            "int32",
"subflow_bwd_bytes":              "int32",
"init_win_bytes_forward":         "int32",
"init_win_bytes_backward":        "int32",
"act_data_pkt_fwd":               "int32",
"min_seg_size_forward":           "int32",
"active_mean":                    "float32",
"active_std":                     "float32",
"active_max":                     "int32",
"active_min":                     "int32",
"idle_mean":                      "float32",
"idle_std":                       "float32",
"idle_max":                       "int32",
"idle_min":                       "int32",
"label":                          "category"
}

# %%
import gc
training_data = None
full_data = None
gc.collect()
# Out:
# 2911

# %%
path = "/Users/kyletopasna/Documents/hunter/ISCX CIC/CIC-IDS-2017/"
data = pd.read_csv(path + "train.csv", dtype=dtypes)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5661486 entries, 0 to 5661485
# Data columns (total 79 columns):
# destination_port               int32
# flow_duration                  int32
# total_fwd_packets              int32
# total_backward_packets         int32
# total_length_of_fwd_packets    int32
# total_length_of_bwd_packets    int32
# fwd_packet_length_max          int32
# fwd_packet_length_min          int32
# fwd_packet_length_mean         float32
# fwd_packet_length_std          float32
# bwd_packet_length_max          int32
# bwd_packet_length_min          int32
# bwd_packet_length_mean         float32
# bwd_packet_length_std          float32
# flow_bytes/s                   float32
# flow_packets/s                 float32
# flow_iat_mean                  float32
# flow_iat_std                   float32
# flow_iat_max                   int32
# flow_iat_min                   int32
# fwd_iat_total                  int32
# fwd_iat_mean                   float32
# ...

# %%
data.columns
# Out:
# Index(['destination_port', 'flow_duration', 'total_fwd_packets',
#        'total_backward_packets', 'total_length_of_fwd_packets',
#        'total_length_of_bwd_packets', 'fwd_packet_length_max',
#        'fwd_packet_length_min', 'fwd_packet_length_mean',
#        'fwd_packet_length_std', 'bwd_packet_length_max',
#        'bwd_packet_length_min', 'bwd_packet_length_mean',
#        'bwd_packet_length_std', 'flow_bytes/s', 'flow_packets/s',
#        'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min',
#        'fwd_iat_total', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max',
#        'fwd_iat_min', 'bwd_iat_total', 'bwd_iat_mean', 'bwd_iat_std',
#        'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'bwd_psh_flags',
#        'fwd_urg_flags', 'bwd_urg_flags', 'fwd_header_length',
#        'bwd_header_length', 'fwd_packets/s', 'bwd_packets/s',
#        'min_packet_length', 'max_packet_length', 'packet_length_mean',
# ...

# %%
data.head()
# Out:
#    destination_port  flow_duration  total_fwd_packets  total_backward_packets  \
# 0             55576              3                  2                       0
# 1                53        7990546                  4                       4
# 2                53       44075460                  2                       2
# 3                80             88                  2                       0
# 4               443       24365639                 36                      38
#
#    total_length_of_fwd_packets  total_length_of_bwd_packets  \
# 0                          280                            0
# 1                          156                          220
# 2                           95                          172
# 3                           12                            0
# 4                          686                        52748
#
#    fwd_packet_length_max  fwd_packet_length_min  fwd_packet_length_mean  \
# ...
