# %%
import glob
import tensorflow as tf 
import numpy as np
import pandas as pd
from scapy.all import *
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
pcap = rdpcap("/Users/kyletopasna/Documents/hunter/pcap/1548216696.814641.pcap")

# %%
pcap
# Out:
# <1548216696.814641.pcap: TCP:119 UDP:38 ICMP:0 Other:7>

# %%
# Retrieving a single item from packet list
ethernet_frame = pcap[0]
ip_packet = ethernet_frame.payload
segment = ip_packet.payload
data = segment.payload # Retrieve payload that comes after layer 4

# Observe that we just popped off previous layer header
print(ethernet_frame.summary())
print(ip_packet.summary())
print(segment.summary())
print(data.summary()) # If blank, empty object

# Complete depiction of paket
## Achieving understanding that these are the fields will enable the ability 
## to ask the data more meaningful questions ie) type of layer 4 segment is defined in layer 3 packet
ethernet_frame.show()
# Out:
# 802.3 38:8b:59:c5:da:3f > 01:80:c2:00:00:00 / LLC / STP
# LLC / STP
# STP
#
# ###[ 802.3 ]###
#   dst       = 01:80:c2:00:00:00
#   src       = 38:8b:59:c5:da:3f
#   len       = 38
# ###[ LLC ]###
#      dsap      = 0x42
#      ssap      = 0x42
#      ctrl      = 3
# ###[ Spanning Tree Protocol ]###
#         proto     = 0
#         version   = 0
#         bpdutype  = 0
#         bpduflags = 0
#         rootid    = 31488
#         rootmac   = 38:8b:59:c5:da:3d
#         pathcost  = 0
#         bridgeid  = 31488
#         bridgemac = 38:8b:59:c5:da:3d
#         portid    = 32772
#         age       = 0.0
#         maxage    = 6.0
#         hellotime = 2.0
#         fwddelay  = 3.0

# %% [markdown]
# Test code for organizing numerical information from packets in a pandas dataframe.
#
# Ref : https://secdevops.ai/learning-packet-analysis-with-data-science-5356a3340d4e

# %%
# Collect field names from IP/TCP/UDP (These will be columns in DF)
ip_fields = [field.name for field in IP().fields_desc]
tcp_fields = [field.name for field in TCP().fields_desc]
udp_fields = [field.name for field in UDP().fields_desc]

dataframe_fields = ip_fields + ['time'] + tcp_fields + ['payload','payload_raw','payload_hex']

# Create blank DataFrame
df = pd.DataFrame(columns=dataframe_fields)
for packet in pcap[IP]:
    # Field array for each row of DataFrame
    field_values = []
    # Add all IP fields to dataframe
    for field in ip_fields:
        if field == 'options':
            # Retrieving number of options defined in IP Header
            field_values.append(len(packet[IP].fields[field]))
        else:
            field_values.append(packet[IP].fields[field])
    
    field_values.append(packet.time)
    
    layer_type = type(packet[IP].payload)
    for field in tcp_fields:
        try:
            if field == 'options':
                field_values.append(len(packet[layer_type].fields[field]))
            else:
                field_values.append(packet[layer_type].fields[field])
        except:
            field_values.append(None)
    
    # Append payload
    field_values.append(len(packet[layer_type].payload))
    field_values.append(packet[layer_type].payload.original)
    field_values.append(binascii.hexlify(packet[layer_type].payload.original))
    # Add row to DF
    df_append = pd.DataFrame([field_values], columns=dataframe_fields)
    df = pd.concat([df, df_append], axis=0)

# Reset Index
df = df.reset_index()
# Drop old index column
df = df.drop(columns="index")

# %%
df.head()
# Out:
#   version ihl tos  len     id flags frag  ttl proto chksum  \
# 0       4   5   0   91  61340          0  255    17  54331
# 1       4   5   0  169      0    DF    0   64     6   3283
# 2       4   5   0  169  57133    DF    0   64     6  11685
# 3       4   5   0   52      0    DF    0   64     6   3400
# 4       4   5   0  115      0    DF    0   64     6  10725
#
#                          ...                         dataofs reserved flags  \
# 0                        ...                            None     None  None
# 1                        ...                               8        0    PA
# 2                        ...                               8        0    PA
# 3                        ...                               8        0     A
# 4                        ...                               8        0    PA
#
#    window chksum urgptr options payload  \
# 0    None    762   None    None      63
# 1    2048   1535      0       3     117
# 2     277  46358      0       3     117
# 3    2046  41450      0       3       0
# 4    2048  52217      0       3      63
#
#                                          payload_raw  \
# 0  b'\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00...
# 1  b'\x17\x03\x03\x00p\x00\x00\x00\x00\x00\x00\x0...
# 2  b'\x17\x03\x03\x00p\x00\x00\x00\x00\x00\x00\x0...
# 3                                                b''
# 4  b'\x17\x03\x03\x00:\x00\x00\x00\x00\x00\x00\x0...
#
#                                          payload_hex
# 0  b'00000000000100000000000012416c656b7a616e6472...
# 1  b'17030300700000000000000590887b2f38441f44547d...
# 2  b'1703030070000000000000058ecb8c1f43bfac224984...
# 3                                                b''
# 4  b'170303003a00000000000002cffad9981bef8e74efb8...
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['version', 'ihl', 'tos', 'len', 'id', 'flags', 'frag', 'ttl', 'proto',
#        'chksum', 'src', 'dst', 'options', 'time', 'sport', 'dport', 'seq',
#        'ack', 'dataofs', 'reserved', 'flags', 'window', 'chksum', 'urgptr',
#        'options', 'payload', 'payload_raw', 'payload_hex'],
#       dtype='object')

# %%
df[["src","sport","dst","dport"]]
# Out:
#                 src  sport              dst  dport
# 0     192.168.86.21   5353      224.0.0.251   5353
# 1     192.168.86.21  60604    192.168.86.22   8009
# 2     192.168.86.22   8009    192.168.86.21  60604
# 3     192.168.86.21  60604    192.168.86.22   8009
# 4     192.168.86.21  60832    34.212.215.14    443
# 5     192.168.86.21  12480     192.168.86.1     53
# 6     34.212.215.14    443    192.168.86.21  60832
# 7     192.168.86.21  60832    34.212.215.14    443
# 8     192.168.86.21  49170     192.168.86.1     53
# 9     192.168.86.26  49154  255.255.255.255   6666
# 10     192.168.86.1     53    192.168.86.21  12480
# 11    192.168.86.21  63068      52.84.19.49    443
# 12     192.168.86.1     53    192.168.86.21  49170
# 13    192.168.86.21  63069   172.217.14.206    443
# 14      52.84.19.49    443    192.168.86.21  63068
# 15    192.168.86.21  63068      52.84.19.49    443
# 16    192.168.86.21  63068      52.84.19.49    443
# 17   172.217.14.206    443    192.168.86.21  63069
# 18    192.168.86.21  63069   172.217.14.206    443
# 19    192.168.86.21  63069   172.217.14.206    443
# 20      52.84.19.49    443    192.168.86.21  63068
# 21      52.84.19.49    443    192.168.86.21  63068
# 22    192.168.86.21  63068      52.84.19.49    443
# 23    192.168.86.21  63068      52.84.19.49    443
# 24    192.168.86.21  63068      52.84.19.49    443
# 25    192.168.86.21  63068      52.84.19.49    443
# 26   172.217.14.206    443    192.168.86.21  63069
# 27   172.217.14.206    443    192.168.86.21  63069
# 28    192.168.86.21  63069   172.217.14.206    443
# 29    192.168.86.21  63069   172.217.14.206    443
# ..              ...    ...              ...    ...
# 125   192.168.86.21  63070      64.4.54.254    443
# 126   192.168.86.21  63070      64.4.54.254    443
# 127   192.168.86.21  63058    34.232.24.250    443
# 128     64.4.54.254    443    192.168.86.21  63070
# 129   192.168.86.21  63070      64.4.54.254    443
# 130   192.168.86.21  63070      64.4.54.254    443
# 131   34.232.24.250    443    192.168.86.21  63058
# 132   34.232.24.250    443    192.168.86.21  63058
# 133   192.168.86.21  63058    34.232.24.250    443
# 134   192.168.86.21  63058    34.232.24.250    443
# 135     64.4.54.254    443    192.168.86.21  63070
# 136   192.168.86.21  63070      64.4.54.254    443
# 137   192.168.86.21  63070      64.4.54.254    443
# 138   192.168.86.21  63070      64.4.54.254    443
# 139     64.4.54.254    443    192.168.86.21  63070
# 140   192.168.86.29  17500  255.255.255.255  17500
# 141   192.168.86.29  17500  255.255.255.255  17500
# 142   192.168.86.29  17500  255.255.255.255  17500
# 143   192.168.86.29  17500  255.255.255.255  17500
# 144   192.168.86.29  17500  255.255.255.255  17500
# 145   192.168.86.29  17500   192.168.86.255  17500
# 146   192.168.86.21  63058    34.232.24.250    443
# 147   192.168.86.21  60700   100.26.125.169    443
# 148   34.232.24.250    443    192.168.86.21  63058
# 149   192.168.86.21  63058    34.232.24.250    443
# 150   34.232.24.250    443    192.168.86.21  63058
# 151   192.168.86.21  63058    34.232.24.250    443
# 152  100.26.125.169    443    192.168.86.21  60700
# 153  100.26.125.169    443    192.168.86.21  60700
# 154   192.168.86.21  60700   100.26.125.169    443
#
# [155 rows x 4 columns]

# %% [markdown]
# We just saw a bunch of packets flowing back and forth, but it's hard to pick out individual streams. Here we present a function that builds bidirectional flows.
#
# ref: https://pen-testing.sans.org/blog/2017/10/13/scapy-full-duplex-stream-reassembly

# %%
def get_sessions(packet):
    sess = "Other"
    if "Ether" in packet:
        if "IP" in packet:
            if "TCP" in packet:
                sess = str(sorted(["TCP", packet["IP"].src, packet["TCP"].sport,
                                  packet["IP"].dst, packet["TCP"].dport], key=str))
            elif "UDP" in packet:
                sess = str(sorted(["UDP", packet["IP"].src, packet["UDP"].sport,
                                  packet["IP"].dst, packet["UDP"].dport], key=str))
            elif "ICMP" in packet:
                sess = str(sorted(["ICMP", packet["IP"].src, packet["IP"].dst,
                                  packet["ICMP"].code, packet["ICMP"].type, packet["ICMP"].id], key=str))
            else:
                sess = str(sorted(["IP", packet["IP"].src, packet["IP"].dst,
                                  packet["IP"].proto], key=str))
        elif "ARP" in packet:
            sess = str(sorted(["ARP", packet["ARP"].psrc, packet["ARP"].pdst], key=str))
        else:
            sess = packet.sprintf("Ethernet type = %04xr,Ether.type%")
    return sess

# %%
bi_directional_sessions = pcap.sessions(get_sessions)
len(bi_directional_sessions)
# Out:
# 23

# %%
for flow in bi_directional_sessions:
    print(flow)
# Out:
# Other
# ['192.168.86.21', '224.0.0.251', 5353, 5353, 'UDP']
# Ethernet type = 86dd
# ['192.168.86.21', '192.168.86.22', 60604, 8009, 'TCP']
# ['192.168.86.21', '34.212.215.14', 443, 60832, 'TCP']
# [12480, '192.168.86.1', '192.168.86.21', 53, 'UDP']
# ['192.168.86.1', '192.168.86.21', 49170, 53, 'UDP']
# ['192.168.86.26', '255.255.255.255', 49154, 6666, 'UDP']
# ['192.168.86.21', 443, '52.84.19.49', 63068, 'TCP']
# ['172.217.14.206', '192.168.86.21', 443, 63069, 'TCP']
# ['104.115.156.95', '192.168.86.21', 443, 61432, 'TCP']
# ['192.168.86.21', 5228, 60605, '74.125.20.188', 'TCP']
# ['192.168.86.1', '192.168.86.21', 'ARP']
# [1900, '192.168.86.249', '239.255.255.250', 44673, 'UDP']
# ['162.254.195.45', '192.168.86.21', 27018, 52731, 'UDP']
# ['192.168.86.21', 443, 63066, '64.71.168.222', 'TCP']
# [1900, '192.168.86.1', '239.255.255.250', 50979, 'UDP']
# ['192.168.86.21', '34.232.24.250', 443, 63058, 'TCP']
# ['162.125.34.129', '192.168.86.21', 443, 62944, 'TCP']
# ['192.168.86.21', 443, 63070, '64.4.54.254', 'TCP']
# [17500, 17500, '192.168.86.29', '255.255.255.255', 'UDP']
# [17500, 17500, '192.168.86.255', '192.168.86.29', 'UDP']
# ['100.26.125.169', '192.168.86.21', 443, 60700, 'TCP']

# %%
bi_directional_sessions
# Out:
# {'Ethernet type = 86dd': <PacketList: TCP:0 UDP:2 ICMP:0 Other:0>,
#  'Other': <PacketList: TCP:0 UDP:0 ICMP:0 Other:5>,
#  "['100.26.125.169', '192.168.86.21', 443, 60700, 'TCP']": <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  "['104.115.156.95', '192.168.86.21', 443, 61432, 'TCP']": <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>,
#  "['162.125.34.129', '192.168.86.21', 443, 62944, 'TCP']": <PacketList: TCP:6 UDP:0 ICMP:0 Other:0>,
#  "['162.254.195.45', '192.168.86.21', 27018, 52731, 'UDP']": <PacketList: TCP:0 UDP:2 ICMP:0 Other:0>,
#  "['172.217.14.206', '192.168.86.21', 443, 63069, 'TCP']": <PacketList: TCP:26 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.1', '192.168.86.21', 'ARP']": <PacketList: TCP:0 UDP:0 ICMP:0 Other:2>,
#  "['192.168.86.1', '192.168.86.21', 49170, 53, 'UDP']": <PacketList: TCP:0 UDP:2 ICMP:0 Other:0>,
#  "['192.168.86.21', '192.168.86.22', 60604, 8009, 'TCP']": <PacketList: TCP:6 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.21', '224.0.0.251', 5353, 5353, 'UDP']": <PacketList: TCP:0 UDP:2 ICMP:0 Other:0>,
#  "['192.168.86.21', '34.212.215.14', 443, 60832, 'TCP']": <PacketList: TCP:9 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.21', '34.232.24.250', 443, 63058, 'TCP']": <PacketList: TCP:23 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.21', 443, '52.84.19.49', 63068, 'TCP']": <PacketList: TCP:18 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.21', 443, 63066, '64.71.168.222', 'TCP']": <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.21', 443, 63070, '64.4.54.254', 'TCP']": <PacketList: TCP:19 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.21', 5228, 60605, '74.125.20.188', 'TCP']": <PacketList: TCP:2 UDP:0 ICMP:0 Other:0>,
#  "['192.168.86.26', '255.255.255.255', 49154, 6666, 'UDP']": <PacketList: TCP:0 UDP:3 ICMP:0 Other:0>,
#  "[12480, '192.168.86.1', '192.168.86.21', 53, 'UDP']": <PacketList: TCP:0 UDP:2 ICMP:0 Other:0>,
#  "[17500, 17500, '192.168.86.255', '192.168.86.29', 'UDP']": <PacketList: TCP:0 UDP:1 ICMP:0 Other:0>,
#  "[17500, 17500, '192.168.86.29', '255.255.255.255', 'UDP']": <PacketList: TCP:0 UDP:5 ICMP:0 Other:0>,
#  "[1900, '192.168.86.1', '239.255.255.250', 50979, 'UDP']": <PacketList: TCP:0 UDP:16 ICMP:0 Other:0>,
#  "[1900, '192.168.86.249', '239.255.255.250', 44673, 'UDP']": <PacketList: TCP:0 UDP:3 ICMP:0 Other:0>}

# %%
bi_directional_sessions[ "['100.26.125.169', '192.168.86.21', 443, 60700, 'TCP']"]
# Out:
# <PacketList: TCP:4 UDP:0 ICMP:0 Other:0>

# %%
# Collect field names from IP/TCP/UDP (These will be columns in DF)

def build_dataframe(packet_list):

    ip_fields = [field.name for field in IP().fields_desc]
    tcp_fields = [field.name for field in TCP().fields_desc]
    udp_fields = [field.name for field in UDP().fields_desc]

    dataframe_fields = ip_fields + ['time'] + tcp_fields + ["size", 'payload','payload_raw','payload_hex']

    # Create blank DataFrame
    df = pd.DataFrame(columns=dataframe_fields)
    for packet in pcap[IP]:
        # Field array for each row of DataFrame
        field_values = []
        # Add all IP fields to dataframe
        for field in ip_fields:
            if field == 'options':
                # Retrieving number of options defined in IP Header
                field_values.append(len(packet[IP].fields[field]))
            else:
                field_values.append(packet[IP].fields[field])

        field_values.append(packet.time)

        layer_type = type(packet[IP].payload)
        for field in tcp_fields:
            try:
                if field == 'options':
                    field_values.append(len(packet[layer_type].fields[field]))
                else:
                    field_values.append(packet[layer_type].fields[field])
            except:
                field_values.append(None)

        # Append payload
        field_values.append(len(packet[layer_type].payload))
        field_values.append(packet[layer_type].payload.original)
        field_values.append(binascii.hexlify(packet[layer_type].payload.original))
        # Add row to DF
        df_append = pd.DataFrame([field_values], columns=dataframe_fields)
        df = pd.concat([df, df_append], axis=0)

    # Reset Index
    df = df.reset_index()
    # Drop old index column
    df = df.drop(columns="index")
    return df

# %%
test_flow = build_dataframe(bi_directional_sessions[ "['100.26.125.169', '192.168.86.21', 443, 60700, 'TCP']"])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-55-dae60136c44b> in <module>()
# ----> 1 test_flow = build_dataframe(bi_directional_sessions[ "['100.26.125.169', '192.168.86.21', 443, 60700, 'TCP']"])
#
# <ipython-input-54-8893b7091a73> in build_dataframe(packet_list)
#      39         field_values.append(binascii.hexlify(packet[layer_type].payload.original))
#      40         # Add row to DF
# ---> 41         df_append = pd.DataFrame([field_values], columns=dataframe_fields)
#      42         df = pd.concat([df, df_append], axis=0)
#      43
#
# /Users/kyletopasna/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     367                     if is_named_tuple(data[0]) and columns is None:
#     368                         columns = data[0]._fields
# --> 369                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     370                     columns = _ensure_index(columns)
#     371
#
# /Users/kyletopasna/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    6282     if isinstance(data[0], (list, tuple)):
#    6283         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# -> 6284                                dtype=dtype)
#    6285     elif isinstance(data[0], collections.Mapping):
#    6286         return _list_of_dict_to_arrays(data, columns,
#
# /Users/kyletopasna/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _list_to_arrays(data, columns, coerce_float, dtype)
#    6361         content = list(lib.to_object_array(data).T)
#    6362     return _convert_object_array(content, columns, dtype=dtype,
# -> 6363                                  coerce_float=coerce_float)
#    6364
#    6365
#
# /Users/kyletopasna/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _convert_object_array(content, columns, coerce_float, dtype)
#    6418             # caller's responsibility to check for this...
#    6419             raise AssertionError('%d columns passed, passed data had %s '
# -> 6420                                  'columns' % (len(columns), len(content)))
#    6421
#    6422     # provide soft conversion of object dtypes
#
# AssertionError: 29 columns passed, passed data had 28 columns

# %%
test_flow
# Out:
#     version ihl tos   len     id flags frag  ttl proto chksum  \
# 0         4   5   0    91  61340          0  255    17  54331
# 1         4   5   0   169      0    DF    0   64     6   3283
# 2         4   5   0   169  57133    DF    0   64     6  11685
# 3         4   5   0    52      0    DF    0   64     6   3400
# 4         4   5   0   115      0    DF    0   64     6  10725
# 5         4   5   0    55  44531          0   64    17  40795
# 6         4   5   0   115   7472    DF    0   41     6   9141
# 7         4   5   0    52      0    DF    0   64     6  10788
# 8         4   5   0    70  34278          0   64    17  51033
# 9         4   5   0   203  59728          0  255    17  47886
# 10        4   5   0    71  37088    DF    0   64    17  31838
# 11        4   5   0    64      0    DF    0   64     6  56437
# 12        4   5   0   107  37091    DF    0   64    17  31799
# 13        4   5   0    64      0    DF    0   64     6  26707
# 14        4   5   0    60      0    DF    0  243     6  10617
# 15        4   5   0    52      0    DF    0   64     6  56449
# 16        4   5   0   569      0    DF    0   64     6  55932
# 17        4   5   0    60   3627          0  118     6  25644
# 18        4   5   0    52      0    DF    0   64     6  26719
# 19        4   5   0   591      0    DF    0   64     6  26180
# 20        4   5   0    52  37443    DF    0  243     6  38717
# 21        4   5   0   198  37444    DF    0  243     6  38570
# 22        4   5   0    52      0    DF    0   64     6  56449
# 23        4   5   0   103      0    DF    0   64     6  56398
# 24        4   5   0   145      0    DF    0   64     6  56356
# 25        4   5   0  1057      0    DF    0   64     6  55444
# 26        4   5   0    52   3685          0  118     6  25594
# 27        4   5   0   208   3686          0  118     6  25437
# 28        4   5   0    52      0    DF    0   64     6  26719
# 29        4   5   0   103      0    DF    0   64     6  26668
# ..      ...  ..  ..   ...    ...   ...  ...  ...   ...    ...
# 125       4   5   0    52      0    DF    0   64     6  44292
# 126       4   5   0   178      0    DF    0   64     6  44166
# 127       4   5   0   104      0    DF    0   64     6  59376
# 128       4   5   0   103   7810    DF    0  109     6  24911
# 129       4   5   0    52      0    DF    0   64     6  44292
# 130       4   5   0   817      0    DF    0   64     6  43527
# 131       4   5   0    94  38101    DF    0  235     6  43044
# 132       4   5   0    96  38102    DF    0  235     6  43041
# 133       4   5   0    52      0    DF    0   64     6  59428
# 134       4   5   0    52      0    DF    0   64     6  59428
# 135       4   5   0   366   7811    DF    0  109     6  24647
# 136       4   5   0    52      0    DF    0   64     6  44292
# 137       4   5   0    83      0    DF    0   64     6  44261
# 138       4   5   0    52      0    DF    0   64     6  44292
# 139       4   5   0    52   7812    DF    0  109     6  24960
# 140       4   5   0   194  19837          0  128    17  54760
# 141       4   5   0   194  19838          0  128    17  54759
# 142       4   5   0   194  19839          0  128    17  54758
# 143       4   5   0   194  19840          0  128    17  54757
# 144       4   5   0   194  19841          0  128    17  54756
# 145       4   5   0   194  18349          0  128    17  50192
# 146       4   5   0   108      0    DF    0   64     6  59372
# 147       4   5   0   340      0    DF    0   64     6  16675
# 148       4   5   0    93  38103    DF    0  235     6  43043
# 149       4   5   0    52      0    DF    0   64     6  59428
# 150       4   5   0    95  38104    DF    0  235     6  43040
# 151       4   5   0    52      0    DF    0   64     6  59428
# 152       4   5   0    52  12886    DF    0  232     6  26604
# 153       4   5   0   377  12887    DF    0  232     6  26278
# 154       4   5   0    52      0    DF    0   64     6  16963
#
#                            ...                         dataofs reserved flags  \
# 0                          ...                            None     None  None
# 1                          ...                               8        0    PA
# 2                          ...                               8        0    PA
# 3                          ...                               8        0     A
# 4                          ...                               8        0    PA
# 5                          ...                            None     None  None
# 6                          ...                               8        0    PA
# 7                          ...                               8        0     A
# 8                          ...                            None     None  None
# 9                          ...                            None     None  None
# 10                         ...                            None     None  None
# 11                         ...                              11        0     S
# 12                         ...                            None     None  None
# 13                         ...                              11        0     S
# 14                         ...                              10        0    SA
# 15                         ...                               8        0     A
# 16                         ...                               8        0    PA
# 17                         ...                              10        0    SA
# 18                         ...                               8        0     A
# 19                         ...                               8        0    PA
# 20                         ...                               8        0     A
# 21                         ...                               8        0    PA
# 22                         ...                               8        0     A
# 23                         ...                               8        0    PA
# 24                         ...                               8        0    PA
# 25                         ...                               8        0    PA
# 26                         ...                               8        0     A
# 27                         ...                               8        0    PA
# 28                         ...                               8        0     A
# 29                         ...                               8        0    PA
# ..                         ...                             ...      ...   ...
# 125                        ...                               8        0     A
# 126                        ...                               8        0    PA
# 127                        ...                               8        0    PA
# 128                        ...                               8        0    PA
# 129                        ...                               8        0     A
# 130                        ...                               8        0    PA
# 131                        ...                               8        0    PA
# 132                        ...                               8        0    PA
# 133                        ...                               8        0     A
# 134                        ...                               8        0     A
# 135                        ...                               8        0   FPA
# 136                        ...                               8        0     A
# 137                        ...                               8        0    PA
# 138                        ...                               8        0    FA
# 139                        ...                               8        0     A
# 140                        ...                            None     None  None
# 141                        ...                            None     None  None
# 142                        ...                            None     None  None
# 143                        ...                            None     None  None
# 144                        ...                            None     None  None
# 145                        ...                            None     None  None
# 146                        ...                               8        0    PA
# 147                        ...                               8        0    PA
# 148                        ...                               8        0    PA
# 149                        ...                               8        0     A
# 150                        ...                               8        0    PA
# 151                        ...                               8        0     A
# 152                        ...                               8        0     A
# 153                        ...                               8        0    PA
# 154                        ...                               8        0     A
#
#      window chksum urgptr options payload  \
# 0      None    762   None    None      63
# 1      2048   1535      0       3     117
# 2       277  46358      0       3     117
# 3      2046  41450      0       3       0
# 4      2048  52217      0       3      63
# 5      None  20707   None    None      27
# 6         9  54718      0       3      63
# 7      2047  12515      0       3       0
# 8      None  28062   None    None      42
# 9      None    214   None    None     175
# 10     None  64825   None    None      43
# 11    65535  21397      0       8       0
# 12     None  42114   None    None      79
# 13    65535  30586      0       8       0
# 14    28960  30367      0       5       0
# 15     2058   3665      0       3       0
# 16     2058  14151      0       3     517
# 17    60192  25879      0       5       0
# 18     2052  30327      0       3       0
# 19     2052  52879      0       3     539
# 20      118   5078      0       3       0
# 21      118   7226      0       3     146
# 22     2056   2940      0       3       0
# 23     2056  13738      0       3      51
# 24     2056  32563      0       3      93
# 25     2056   9744      0       3    1005
# 26      240  31538      0       3       0
# 27      240  19350      0       3     156
# 28     2049  29513      0       3       0
# 29     2049   5869      0       3      51
# ..      ...    ...    ...     ...     ...
# 125    2048    153      0       3       0
# 126    2048   8262      0       3     126
# 127    2048  23451      0       3      52
# 128    1028  60938      0       3      51
# 129    2047  65343      0       3       0
# 130    2048  57683      0       3     765
# 131     126  38383      0       3      42
# 132     126  37113      0       3      44
# 133    2047  27895      0       3       0
# 134    2046  27851      0       3       0
# 135    1025  47682      0       3     314
# 136    2043  64031      0       3       0
# 137    2048  28158      0       3      31
# 138    2048  63993      0       3       0
# 139    1025  64928      0       3       0
# 140    None  28167   None    None     166
# 141    None  28167   None    None     166
# 142    None  28167   None    None     166
# 143    None  28167   None    None     166
# 144    None  28167   None    None     166
# 145    None  22111   None    None     166
# 146    2048  65501      0       3      56
# 147    2048  23413      0       3     288
# 148     126  13181      0       3      41
# 149    2047  25697      0       3       0
# 150     126   3537      0       3      43
# 151    2047  25653      0       3       0
# 152     766  11216      0       3       0
# 153     766  61593      0       3     325
# 154    2042   9474      0       3       0
#
#                                            payload_raw  \
# 0    b'\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00...
# 1    b'\x17\x03\x03\x00p\x00\x00\x00\x00\x00\x00\x0...
# 2    b'\x17\x03\x03\x00p\x00\x00\x00\x00\x00\x00\x0...
# 3                                                  b''
# 4    b'\x17\x03\x03\x00:\x00\x00\x00\x00\x00\x00\x0...
# 5    b'\x05W\x01\x00\x00\x01\x00\x00\x00\x00\x00\x0...
# 6    b"\x17\x03\x03\x00:[\xb8@\x91>\xcb\xf0\xf6\xbf...
# 7                                                  b''
# 8    b'\x07\x80\x01\x00\x00\x01\x00\x00\x00\x00\x00...
# 9    b'\x00\x00U\xaa\x00\x00\x00\x00\x00\x00\x00\x0...
# 10   b'\x05W\x81\x80\x00\x01\x00\x01\x00\x00\x00\x0...
# 11                                                 b''
# 12   b'\x07\x80\x81\x80\x00\x01\x00\x02\x00\x00\x00...
# 13                                                 b''
# 14                                                 b''
# 15                                                 b''
# 16   b'\x16\x03\x01\x02\x00\x01\x00\x01\xfc\x03\x03...
# 17                                                 b''
# 18                                                 b''
# 19   b'\x16\x03\x01\x02\x16\x01\x00\x02\x12\x03\x03...
# 20                                                 b''
# 21   b'\x16\x03\x03\x00Z\x02\x00\x00V\x03\x03\\\x8f...
# 22                                                 b''
# 23   b'\x14\x03\x03\x00\x01\x01\x16\x03\x03\x00(\x0...
# 24   b'\x17\x03\x03\x00X\x00\x00\x00\x00\x00\x00\x0...
# 25   b'\x17\x03\x03\x03\xe8\x00\x00\x00\x00\x00\x00...
# 26                                                 b''
# 27   b"\x16\x03\x03\x00d\x02\x00\x00`\x03\x03\\G\xe...
# 28                                                 b''
# 29   b'\x14\x03\x03\x00\x01\x01\x16\x03\x03\x00(\x0...
# ..                                                 ...
# 125                                                b''
# 126  b'\x16\x03\x03\x00F\x10\x00\x00BA\x04\x0f\x8e\...
# 127  b'\x17\x03\x03\x00/\x00\x00\x00\x00\x00\x00\x0...
# 128  b'\x14\x03\x03\x00\x01\x01\x16\x03\x03\x00(\x0...
# 129                                                b''
# 130  b'\x17\x03\x03\x02\xf8I\xbch+\xee\x0f\xf6u\xc1...
# 131  b'\x17\x03\x03\x00%\x15f\x8b\xc3IgC\xa0\xb0!\x...
# 132  b'\x17\x03\x03\x00\'\x15f\x8b\xc3IgC\xa1\xd4\x...
# 133                                                b''
# 134                                                b''
# 135  b'\x17\x03\x03\x015\x00\x00\x00\x00\x00\x00\x0...
# 136                                                b''
# 137  b'\x15\x03\x03\x00\x1aI\xbch+\xee\x0f\xf6v\xf0...
# 138                                                b''
# 139                                                b''
# 140  b'{"version": [2, 0], "port": 17500, "host_int...
# 141  b'{"version": [2, 0], "port": 17500, "host_int...
# 142  b'{"version": [2, 0], "port": 17500, "host_int...
# 143  b'{"version": [2, 0], "port": 17500, "host_int...
# 144  b'{"version": [2, 0], "port": 17500, "host_int...
# 145  b'{"version": [2, 0], "port": 17500, "host_int...
# 146  b'\x17\x03\x03\x003\x00\x00\x00\x00\x00\x00\x0...
# 147  b'\x17\x03\x03\x01\x1b\x00\x00\x00\x00\x00\x00...
# 148  b'\x17\x03\x03\x00$\x15f\x8b\xc3IgC\xa2SO\xf1k...
# 149                                                b''
# 150  b'\x17\x03\x03\x00&\x15f\x8b\xc3IgC\xa3\tn|\x8...
# 151                                                b''
# 152                                                b''
# 153  b'\x17\x03\x03\x01@\xd1FW\xf2!It}\xa0\xba\xfb\...
# 154                                                b''
#
#                                            payload_hex
# 0    b'00000000000100000000000012416c656b7a616e6472...
# 1    b'17030300700000000000000590887b2f38441f44547d...
# 2    b'1703030070000000000000058ecb8c1f43bfac224984...
# 3                                                  b''
# 4    b'170303003a00000000000002cffad9981bef8e74efb8...
# 5    b'05570100000100000000000005736c61636b03636f6d...
# 6    b'170303003a5bb840913ecbf0f6bfa08eb14f827aeb59...
# 7                                                  b''
# 8    b'0780010000010000000000000d6e6f74696669636174...
# 9    b'000055aa00000000000000000000009f000000007b22...
# 10   b'05578180000100010000000005736c61636b03636f6d...
# 11                                                 b''
# 12   b'0780818000010002000000000d6e6f74696669636174...
# 13                                                 b''
# 14                                                 b''
# 15                                                 b''
# 16   b'1603010200010001fc03037883e8e112f95d0dbff4eb...
# 17                                                 b''
# 18                                                 b''
# 19   b'1603010216010002120303e3b1af1de085f3129030cc...
# 20                                                 b''
# 21   b'160303005a0200005603035c8f273c480c8a98c06633...
# 22                                                 b''
# 23   b'14030300010116030300280000000000000000de7ffd...
# 24   b'170303005800000000000000012ecaf84bb92fc4fc7e...
# 25   b'17030303e80000000000000002431c2b1608acde0d72...
# 26                                                 b''
# 27   b'16030300640200006003035c47e9702d2744fcc2a1cd...
# 28                                                 b''
# 29   b'14030300010116030300280000000000000000c09edd...
# ..                                                 ...
# 125                                                b''
# 126  b'16030300461000004241040f8e8c5170fdc29ff17718...
# 127  b'170303002f0000000000000007f5e23284240e83a0f2...
# 128  b'14030300010116030300280000000000000000423a26...
# 129                                                b''
# 130  b'17030302f849bc682bee0ff675c16d63c3dc4f6c5db2...
# 131  b'170303002515668bc3496743a0b021d00c3a5b86e8f3...
# 132  b'170303002715668bc3496743a1d4eb002a2fc3708c6b...
# 133                                                b''
# 134                                                b''
# 135  b'1703030135000000000000000189a506e7f0fdc2733c...
# 136                                                b''
# 137  b'150303001a49bc682bee0ff676f078c8e03e72c44aae...
# 138                                                b''
# 139                                                b''
# 140  b'7b2276657273696f6e223a205b322c20305d2c202270...
# 141  b'7b2276657273696f6e223a205b322c20305d2c202270...
# 142  b'7b2276657273696f6e223a205b322c20305d2c202270...
# 143  b'7b2276657273696f6e223a205b322c20305d2c202270...
# 144  b'7b2276657273696f6e223a205b322c20305d2c202270...
# 145  b'7b2276657273696f6e223a205b322c20305d2c202270...
# 146  b'170303003300000000000000088acf4cdc3ceff5d736...
# 147  b'170303011b00000000000000efbefcb39b79d5c1b5c8...
# 148  b'170303002415668bc3496743a2534ff16b89c36a8cac...
# 149                                                b''
# 150  b'170303002615668bc3496743a3096e7c80041ef934ab...
# 151                                                b''
# 152                                                b''
# 153  b'1703030140d14657f22149747da0bafbcaaa5dc116c6...
# 154                                                b''
#
# [155 rows x 28 columns]

# %%
test_flow.columns
# Out:
# Index(['version', 'ihl', 'tos', 'len', 'id', 'flags', 'frag', 'ttl', 'proto',
#        'chksum', 'src', 'dst', 'options', 'time', 'sport', 'dport', 'seq',
#        'ack', 'dataofs', 'reserved', 'flags', 'window', 'chksum', 'urgptr',
#        'options', 'payload', 'payload_raw', 'payload_hex'],
#       dtype='object')

# %%
def get_flow_duration(df):
    idx = df.columns.get_loc("time")
    return df.iloc[-1, idx] - test_flow.iloc[0,idx]

# %%
get_flow_duration(test_flow)
# Out:
# 9.168694019317627

# %%
def
